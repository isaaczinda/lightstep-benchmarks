# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

# measured from the controller
CONTROLLER_CLOCK=1
CONTROLLER_PROGRAM=0
controller_times = [    
    (0.885300713, 0.5316150188446045),
    (0.8896256880000001, 0.5390608310699463),
    (0.887075001, 0.6400110721588135),
    (0.895721195, 0.6493120193481445),
    (0.893513562, 0.6452839374542236),
    (0.898578305, 0.7540609836578369),
    (0.908183474, 0.7610979080200195),
    (0.911840748, 0.7644729614257812),
    (0.907594878, 0.7602798938751221),
    (0.914989379, 0.8739490509033203),
    (0.917695057, 0.8699812889099121),
    (0.9111300809999999, 0.8721990585327148),
    (0.92807544, 0.8883640766143799),
    (0.929280148, 0.8842289447784424),
    (0.92788086, 0.9843220710754395),
    (0.9374799899999999, 1.0000920295715332),
    (0.927658743, 0.9958100318908691),
    (0.94539152, 1.0068638324737549),
    (0.9419938240000001, 1.0002460479736328),
    (0.930227344, 0.9840512275695801),
    (1.236980767, 1.9144890308380127),
    (5.055075039000001, 11.509519100189209),
    
        # next run
    (1.632108848, 2.6118967533111572),
    (1.609862117, 2.5629727840423584),
    (3.037348562, 6.153588056564331),
    (3.046708, 6.141101121902466),
    (5.359428229, 12.019747972488403),
    (10.046016998, 23.839761972427368),
]



# measured from the client
CLIENT_PROGRAM=0
CLIENT_CLOCK=1
client_times = [
    (0.23893808800000005, 0.34002685546875),
    (0.248228432, 0.3495669364929199),
    (0.245286632, 0.45095300674438477),
    (0.25201147199999996, 0.45735692977905273),
    (0.25253454399999997, 0.45981311798095703),
    (0.25833318400000005, 0.5701019763946533),
    (0.26397189600000004, 0.5727097988128662),
    (0.26923786400000005, 0.5770349502563477),
    (0.267451208, 0.5754890441894531),
    (0.2740970640000001, 0.6878821849822998),
    (0.274649296, 0.6820988655090332),
    (0.2683700320000001, 0.6810848712921143),
    (0.281029552, 0.6928501129150391),
    (0.28545452799999993, 0.6942660808563232),
    (0.282416024, 0.7924838066101074),
    (0.287580752, 0.8024709224700928),
    (0.2786804639999999, 0.796396017074585),
    (0.2956784239999999, 0.8083009719848633),
    (0.29483632800000004, 0.8067619800567627),
    (0.286586032, 0.7950448989868164),
    (0.5950758560000001, 1.7265229225158691),
    (4.325008064, 11.233070850372314),
    
    # next run
    (0.9114594, 2.3470630645751953),
    (0.8890213119999999, 2.2985477447509766),
    (2.3153961919999997, 5.8878090381622314),
    (2.326036256, 5.876997232437134),
    (4.642204152, 11.758978128433228),
    (9.328975032, 23.57925295829773),
]




client_clock = [m[CLIENT_CLOCK] for m in client_times]
controller_clock = [a[CONTROLLER_CLOCK] for a in controller_times]

plt.scatter(client_clock, controller_clock, label='clock', color='red')

# calc the trendline
z = np.polyfit(client_clock, controller_clock, 1)
p = np.poly1d(z)
plt.plot(np.arange(0, max(client_clock), .001) , p(np.arange(0, max(client_clock), .001)),"r--", label='clock trendline')
print("clock trendline: y=%.6fx+(%.6f)"%(z[0],z[1]))



client_program = [m[CLIENT_PROGRAM] for m in client_times]
controller_program = [a[CONTROLLER_PROGRAM] for a in controller_times]

plt.scatter(client_program, controller_program, label='program', color='blue')

# calc the trendline
z = np.polyfit(client_program, controller_program, 1)
p = np.poly1d(z)
plt.plot(np.arange(0, max(client_program), .001) , p(np.arange(0, max(client_program), .001)),"b--", label='program trendline')
print("program trendline: y=%.6fx+(%.6f)"%(z[0],z[1]))
plt.legend()

plt.xlabel("client time")
plt.ylabel("controller time")
# Out:
# <img src="data:image/png;base64,..." width="775">
# clock trendline: y=1.004612x+(0.196461)
# program trendline: y=1.012024x+(0.650164)
# Text(0, 0.5, 'controller time')

# %%
# controller takes longer to run when its stand-alone
# controller program time consistently reads longer than client program time (expected). What's unexpected 
# is that the program time y intercept is
